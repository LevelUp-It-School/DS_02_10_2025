# %%
# !pip install pandas

# %%
import pandas as pd

# %%
obj = pd.Series([1, "John", 3.5, "Hey"])
obj
# Out:
# 0       1
# 1    John
# 2     3.5
# 3     Hey
# dtype: object

# %%
obj[1]
# Out:
# 'John'

# %%
obj.values
# Out:
# array([1, 'John', 3.5, 'Hey'], dtype=object)

# %%
obj2 = pd.Series([1, "John", 3.5, "Hey"], index=["a", "b", "c", "d"])
obj2
# Out:
# a       1
# b    John
# c     3.5
# d     Hey
# dtype: object

# %%
obj2['b']
# Out:
# 'John'

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
score = {"Jane":90, "Bill":80,"Elon":85,"Tom":75,"Tim":95}
names = pd.Series(score)
names
# Out:
# Jane    90
# Bill    80
# Elon    85
# Tom     75
# Tim     95
# dtype: int64

# %%
names['Tim']
# Out:
# np.int64(95)

# %%
names[names>=85]
# Out:
# Jane    90
# Elon    85
# Tim     95
# dtype: int64

# %%
names["Tim"] = 60
names
# Out:
# Jane    90
# Bill    80
# Elon    85
# Tom     75
# Tim     60
# dtype: int64

# %%
names[names<=80] = 83
names
# Out:
# Jane    90
# Bill    83
# Elon    85
# Tom     83
# Tim     83
# dtype: int64

# %%
"Tom" in names
# Out:
# True

# %%
"Ken" in names
# Out:
# False

# %%
names/10
# Out:
# Jane    9.0
# Bill    8.3
# Elon    8.5
# Tom     8.3
# Tim     8.3
# dtype: float64

# %%
names ** 2
# Out:
# Jane    8100
# Bill    6889
# Elon    7225
# Tom     6889
# Tim     6889
# dtype: int64

# %%
names.isnull()
# Out:
# Jane    False
# Bill    False
# Elon    False
# Tom     False
# Tim     False
# dtype: bool

# %%
games = pd.read_csv(r"C:\Users\AZubochenko\Desktop\DS\DS_02_10_2025\pandas\vgsalesGlobale.csv")

# %%
games.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
games.Genre.value_counts(normalize=True)
# Out:
# Genre
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: proportion, dtype: float64

# %%
type(games.Genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
games.Genre.value_counts().head()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: count, dtype: int64

# %%
games.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
games.Genre.nunique()
# Out:
# 12

# %%
pd.crosstab(games.Genre, games.Year)
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# Strategy           0       0       0       0       0       0       0       0
#
# Year          1988.0  1989.0  ...  2009.0  2010.0  2011.0  2012.0  2013.0  \
# Genre                         ...
# Action             2       2  ...     272     226     239     266     148
# Adventure          0       0  ...     141     154     108      58      60
# Fighting           0       0  ...      53      40      50      29      20
# Misc               0       1  ...     207     201     184      38      42
# Platform           4       3  ...      29      31      37      12      37
# Puzzle             1       5  ...      79      45      43      11       3
# Racing             1       0  ...      84      57      65      30      16
# Role-Playing       3       2  ...     103     103      95      78      71
# Shooter            1       1  ...      91      81      94      48      59
# Simulation         1       0  ...     123      82      56      18      18
# Sports             2       3  ...     184     186     122      54      53
# Strategy           0       0  ...      65      53      46      15      19
#
# Year          2014.0  2015.0  2016.0  2017.0  2020.0
# Genre
# Action           186     255     119       1       0
# Adventure         75      54      34       0       0
# Fighting          23      21      14       0       0
# Misc              41      39      18       0       0
# Platform          10      14      10       0       0
# Puzzle             8       6       0       0       0
# Racing            27      19      20       0       0
# Role-Playing      91      78      40       2       0
# Shooter           47      34      32       0       0
# Simulation        11      15       9       0       1
# Sports            55      62      38       0       0
# Strategy           8      17      10       0       0
#
# [12 rows x 39 columns]

# %%
games.Global_Sales.describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
games.Global_Sales.mean()
# Out:
# np.float64(0.5374406555006628)

# %%
games.Year.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
games.Genre.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Genre'>

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
df = pd.DataFrame(data, columns=["name", "sport", "sex", "score"])
df
# Out:
#       name      sport sex  score
# 0     Bill  Wrestling   M     90
# 1      Tom   Football   M     80
# 2      Tim     Skiing   M     85
# 3     John   Swimming   M     75
# 4     Alex     Tennis   F     95
# 5  Vanessa     Karete   F     60
# 6     Kate    Surfing   F     65

# %%
df.tail(3)
# Out:
#       name    sport sex  score
# 4     Alex   Tennis   F     95
# 5  Vanessa   Karete   F     60
# 6     Kate  Surfing   F     65

# %%
df = pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling    NaN     90  NaN
# 1      Tom   Football    NaN     80  NaN
# 2      Tim     Skiing    NaN     85  NaN
# 3     John   Swimming    NaN     75  NaN
# 4     Alex     Tennis    NaN     95  NaN
# 5  Vanessa     Karete    NaN     60  NaN
# 6     Kate    Surfing    NaN     65  NaN

# %%
df = pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"], index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90  NaN
# two        Tom   Football    NaN     80  NaN
# three      Tim     Skiing    NaN     85  NaN
# four      John   Swimming    NaN     75  NaN
# five      Alex     Tennis    NaN     95  NaN
# six    Vanessa     Karete    NaN     60  NaN
# seven     Kate    Surfing    NaN     65  NaN

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
my_columns = ["name", "sport"]
df[my_columns]
# Out:
#           name      sport
# one       Bill  Wrestling
# two        Tom   Football
# three      Tim     Skiing
# four      John   Swimming
# five      Alex     Tennis
# six    Vanessa     Karete
# seven     Kate    Surfing

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling    NaN     90  NaN

# %%
df.loc[["one", "two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling    NaN     90  NaN
# two   Tom   Football    NaN     80  NaN

# %%
df['age'] = 18

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   18
# three      Tim     Skiing    NaN     85   18
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   18
# six    Vanessa     Karete    NaN     60   18
# seven     Kate    Surfing    NaN     65   18

# %%
values = [18, 19, 20, 18, 17, 17, 18]

# %%
df['age'] = values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18

# %%
df["passed"] = df.score >= 70
df
# Out:
#           name      sport gender  score  age  passed
# one       Bill  Wrestling    NaN     90   18    True
# two        Tom   Football    NaN     80   19    True
# three      Tim     Skiing    NaN     85   20    True
# four      John   Swimming    NaN     75   18    True
# five      Alex     Tennis    NaN     95   17    True
# six    Vanessa     Karete    NaN     60   17   False
# seven     Kate    Surfing    NaN     65   18   False

# %%
del df['passed']

# %%
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90   18
# two        Tom   Football    NaN     80   19
# three      Tim     Skiing    NaN     85   20
# four      John   Swimming    NaN     75   18
# five      Alex     Tennis    NaN     95   17
# six    Vanessa     Karete    NaN     60   17
# seven     Kate    Surfing    NaN     65   18

# %%
scores={"Math":{"A":85,"B":90,"C":95}, "Physics":{"A":90,"B":80,"C":75}}

# %%
scores_df = pd.DataFrame(scores)
scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.T
# Out:
#           A   B   C
# Math     85  90  95
# Physics  90  80  75

# %%
scores_df.index.name = "name"
scores_df.columns.name = "lesson"
scores_df
# Out:
# lesson  Math  Physics
# name
# A         85       90
# B         90       80
# C         95       75

# %%
scores_df.values
# Out:
# array([[85, 90],
#        [90, 80],
#        [95, 75]])

# %%
import numpy as np

# %%
obj = pd.Series(np.arange(5), index=["a","b","c","d","e"])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
obj['c']
# Out:
# np.int64(2)

# %%
obj[2]
# Out:
# C:\Users\AZubochenko\AppData\Local\Temp\ipykernel_7196\1027971403.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[2]
# np.int64(2)

# %%
obj[0:3]
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj[["a", 'c']]
# Out:
# a    0
# c    2
# dtype: int64

# %%
obj[obj<2]
# Out:
# a    0
# b    1
# dtype: int64

# %%
obj["a":'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj["b":'c'] = 5
obj
# Out:
# a    0
# b    5
# c    5
# d    3
# e    4
# dtype: int64

# %%
data=pd.DataFrame(
    np.arange(16).reshape(4,4),
    index=["London","Paris",
           "Berlin","Istanbul"],
    columns=["one","two","three","four"])

# %%
data
# Out:
#           one  two  three  four
# London      0    1      2     3
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data['two']
# Out:
# London       1
# Paris        5
# Berlin       9
# Istanbul    13
# Name: two, dtype: int64

# %%
data[['one', 'two']]
# Out:
#           one  two
# London      0    1
# Paris       4    5
# Berlin      8    9
# Istanbul   12   13

# %%
data[:3]
# Out:
#         one  two  three  four
# London    0    1      2     3
# Paris     4    5      6     7
# Berlin    8    9     10    11

# %%
data[data['four']>5]
# Out:
#           one  two  three  four
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data[data<5] = 0
data
# Out:
#           one  two  three  four
# London      0    0      0     0
# Paris       0    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data
# Out:
#           one  two  three  four
# London      0    0      0     0
# Paris       0    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data.iloc[1]
# Out:
# one      0
# two      5
# three    6
# four     7
# Name: Paris, dtype: int64

# %%
data.iloc[1, [1,2,3]]
# Out:
# two      5
# three    6
# four     7
# Name: Paris, dtype: int64

# %%
data.iloc[[1, 3], [1, 2, 3]]
# Out:
#           two  three  four
# Paris       5      6     7
# Istanbul   13     14    15

# %%
data.loc["Paris", ["one", "two"]]
# Out:
# one    0
# two    5
# Name: Paris, dtype: int64

# %%
data.loc[:"Paris", "four"]
# Out:
# London    0
# Paris     7
# Name: four, dtype: int64

# %%
s = pd.Series([1,2,3,4], index=["a","b","c","d"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
s2 = s.reindex(["b", "d", 'a', "c", 'e'])
s2
# Out:
# b    2.0
# d    4.0
# a    1.0
# c    3.0
# e    NaN
# dtype: float64

# %%
s3 = pd.Series(['blue', 'yellow', 'purple'],
               index=[0, 2, 4])
s3
# Out:
# 0      blue
# 2    yellow
# 4    purple
# dtype: object

# %%
s3.reindex(range(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    yellow
# 3    yellow
# 4    purple
# 5    purple
# dtype: object

# %%
df=pd.DataFrame(np.arange(9).reshape(3,3),
                index=["a","c","d"],
                columns=["Tim","Tom","Kate"])
df
# Out:
#    Tim  Tom  Kate
# a    0    1     2
# c    3    4     5
# d    6    7     8

# %%
df2 = df.reindex(['d', 'c', 'b', 'a'])
df2
# Out:
#    Tim  Tom  Kate
# d  6.0  7.0   8.0
# c  3.0  4.0   5.0
# b  NaN  NaN   NaN
# a  0.0  1.0   2.0

# %%
names = ["Kate", "Tim","Tom"]
df.reindex(columns=names)
# Out:
#    Kate  Tim  Tom
# a     2    0    1
# c     5    3    4
# d     8    6    7

# %%
df.loc[['c', 'd', 'a']]
# Out:
#    Tim  Tom  Kate
# c    3    4     5
# d    6    7     8
# a    0    1     2

# %%
s=pd.Series(np.arange(5.),
            index=["a","b","c","d","e"])
s
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_s = s.drop('b')
new_s
# Out:
# a    0.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
s.drop(['c', 'd'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data=pd.DataFrame(np.arange(16).reshape(4,4),
                  index=["Kate","Tim",
                         "Tom","Alex"],
                  columns=list("ABCD"))
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.drop(["Kate", "Tim"])
# Out:
#        A   B   C   D
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.drop('A', axis=1)
# Out:
#        B   C   D
# Kate   1   2   3
# Tim    5   6   7
# Tom    9  10  11
# Alex  13  14  15

# %%
data.drop("Kate", axis=0)
# Out:
#        A   B   C   D
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data.mean(axis='index')
# Out:
# A    6.0
# B    7.0
# C    8.0
# D    9.0
# dtype: float64

# %%
data.mean(axis='columns')
# Out:
# Kate     1.5
# Tim      5.5
# Tom      9.5
# Alex    13.5
# dtype: float64

# %%
df=pd.DataFrame(
    np.random.randn(4,3),
    columns=list("ABC"),
    index=["Kim","Susan","Tim","Tom"])
df
# Out:
#               A         B         C
# Kim    0.114194 -0.296989  0.509434
# Susan  1.365739 -0.522787  0.248371
# Tim   -0.408260  0.468364 -0.151682
# Tom    0.219828 -1.456694  0.265861

# %%
np.abs(df)
# Out:
#               A         B         C
# Kim    0.114194  0.296989  0.509434
# Susan  1.365739  0.522787  0.248371
# Tim    0.408260  0.468364  0.151682
# Tom    0.219828  1.456694  0.265861

# %%
#lambda args: выражение
double = lambda x: x*2
double(5)
# Out:
# 10

# %%
numbers = [1,2,3,4]
list(map(lambda x: x**2, numbers))
# Out:
# [1, 4, 9, 16]

# %%
f = lambda x: x.max() - x.min()
df.apply(f)
# Out:
# A    1.773999
# B    1.925058
# C    0.661115
# dtype: float64

# %%
df.apply(f, axis=1)
# Out:
# Kim      0.806423
# Susan    1.888526
# Tim      0.876624
# Tom      1.722556
# dtype: float64

# %%
def f(x):
    return x**2

# %%
df.apply(f)
# Out:
#               A         B         C
# Kim    0.013040  0.088202  0.259523
# Susan  1.865243  0.273306  0.061688
# Tim    0.166676  0.219365  0.023007
# Tom    0.048324  2.121959  0.070682

# %%
data
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
data = pd.read_csv(r"C:\Users\AZubochenko\Desktop\DS\DS_02_10_2025\pandas\vgsalesGlobale.csv")

# %%
data.to_csv("new_data.csv", sep=';')

# %%
data["Name"].sort_values(ascending=False)
# Out:
# 9135                ¡Shin Chan Flipa en colores!
# 470                   wwe Smackdown vs. Raw 2006
# 15523               uDraw Studio: Instant Artist
# 7835                uDraw Studio: Instant Artist
# 627                                 uDraw Studio
#                           ...
# 8304               .hack//G.U. Vol.3//Redemption
# 8602     .hack//G.U. Vol.2//Reminisce (jp sales)
# 7107                .hack//G.U. Vol.2//Reminisce
# 8357                  .hack//G.U. Vol.1//Rebirth
# 4754                                 '98 Koshien
# Name: Name, Length: 16598, dtype: object

# %%
data.sort_values("Name")
# Out:
#         Rank                                     Name Platform    Year  \
# 4754    4756                              '98 Koshien       PS  1998.0
# 8357    8359               .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 7107    7109             .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# 8602    8604  .hack//G.U. Vol.2//Reminisce (jp sales)      PS2  2006.0
# 8304    8306            .hack//G.U. Vol.3//Redemption      PS2  2007.0
# ...      ...                                      ...      ...     ...
# 627      628                             uDraw Studio      Wii  2010.0
# 7835    7837             uDraw Studio: Instant Artist      Wii  2011.0
# 15523  15526             uDraw Studio: Instant Artist     X360  2011.0
# 470      471               wwe Smackdown vs. Raw 2006      PS2     NaN
# 9135    9137             ¡Shin Chan Flipa en colores!       DS  2007.0
#
#               Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4754         Sports     Magical Company      0.15      0.10      0.12
# 8357   Role-Playing  Namco Bandai Games      0.00      0.00      0.17
# 7107   Role-Playing  Namco Bandai Games      0.11      0.09      0.00
# 8602   Role-Playing  Namco Bandai Games      0.00      0.00      0.16
# 8304   Role-Playing  Namco Bandai Games      0.00      0.00      0.17
# ...             ...                 ...       ...       ...       ...
# 627            Misc                 THQ      1.67      0.58      0.00
# 7835           Misc                 THQ      0.08      0.09      0.00
# 15523          Misc                 THQ      0.01      0.01      0.00
# 470        Fighting                 NaN      1.57      1.02      0.00
# 9135       Platform           505 Games      0.00      0.00      0.14
#
#        Other_Sales  Global_Sales
# 4754          0.03          0.41
# 8357          0.00          0.17
# 7107          0.03          0.23
# 8602          0.00          0.16
# 8304          0.00          0.17
# ...            ...           ...
# 627           0.20          2.46
# 7835          0.02          0.19
# 15523         0.00          0.02
# 470           0.41          3.00
# 9135          0.00          0.14
#
# [16598 rows x 11 columns]

# %%
data.sort_values("Year")
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 544      545              Missile Command     2600  1980.0       Shooter
# 6896    6898                     Checkers     2600  1980.0          Misc
# 4025    4027                   Ice Hockey     2600  1980.0        Sports
# 6317    6319                       Bridge     2600  1980.0          Misc
# 1969    1971                     Defender     2600  1980.0          Misc
# ...      ...                          ...      ...     ...           ...
# 16307  16310                Freaky Flyers       GC     NaN        Racing
# 16327  16330                    Inversion       PC     NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16427  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 544                 Atari      2.56      0.17       0.0         0.03
# 6896                Atari      0.22      0.01       0.0         0.00
# 4025           Activision      0.46      0.03       0.0         0.01
# 6317           Activision      0.25      0.02       0.0         0.00
# 1969                Atari      0.99      0.05       0.0         0.01
# ...                   ...       ...       ...       ...          ...
# 16307             Unknown      0.01      0.00       0.0         0.00
# 16327  Namco Bandai Games      0.01      0.00       0.0         0.00
# 16366             Unknown      0.01      0.00       0.0         0.00
# 16427             Unknown      0.01      0.00       0.0         0.00
# 16493             Unknown      0.00      0.01       0.0         0.00
#
#        Global_Sales
# 544            2.76
# 6896           0.24
# 4025           0.49
# 6317           0.27
# 1969           1.05
# ...             ...
# 16307          0.01
# 16327          0.01
# 16366          0.01
# 16427          0.01
# 16493          0.01
#
# [16598 rows x 11 columns]

# %%
data.sort_values(["Year", "Name"])
# Out:
#         Rank                                        Name Platform    Year  \
# 258      259                                   Asteroids     2600  1980.0
# 2669    2671                                      Boxing     2600  1980.0
# 6317    6319                                      Bridge     2600  1980.0
# 6896    6898                                    Checkers     2600  1980.0
# 1969    1971                                    Defender     2600  1980.0
# ...      ...                                         ...      ...     ...
# 7351    7353              Yu Yu Hakusho: Dark Tournament      PS2     NaN
# 15476  15479  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii     NaN
# 11409  11411                    Zero: Tsukihami no Kamen      Wii     NaN
# 8899    8901                              eJay Clubworld      PS2     NaN
# 470      471                  wwe Smackdown vs. Raw 2006      PS2     NaN
#
#           Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 258     Shooter               Atari      4.00      0.26      0.00
# 2669   Fighting          Activision      0.72      0.04      0.00
# 6317       Misc          Activision      0.25      0.02      0.00
# 6896       Misc               Atari      0.22      0.01      0.00
# 1969       Misc               Atari      0.99      0.05      0.00
# ...         ...                 ...       ...       ...       ...
# 7351   Fighting                 NaN      0.10      0.08      0.00
# 15476    Racing             Unknown      0.00      0.00      0.02
# 11409    Action            Nintendo      0.00      0.00      0.08
# 8899       Misc  Empire Interactive      0.07      0.06      0.00
# 470    Fighting                 NaN      1.57      1.02      0.00
#
#        Other_Sales  Global_Sales
# 258           0.05          4.31
# 2669          0.01          0.77
# 6317          0.00          0.27
# 6896          0.00          0.24
# 1969          0.01          1.05
# ...            ...           ...
# 7351          0.03          0.21
# 15476         0.00          0.02
# 11409         0.00          0.08
# 8899          0.02          0.15
# 470           0.41          3.00
#
# [16598 rows x 11 columns]

# %%
s = pd.Series(["SaM", np.nan, "Tim", "Kim"])
s
# Out:
# 0    SaM
# 1    NaN
# 2    Tim
# 3    Kim
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
s[3] = None
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s.dropna()
# Out:
# 0    SaM
# 2    Tim
# dtype: object

# %%
from numpy import nan as NA

# %%
df=pd.DataFrame([[1,2,3],[4,NA,5],
                 [NA,NA,NA]])
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0
# 2  NaN  NaN  NaN

# %%
df.dropna()
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
df.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0

# %%
df[1] = NA

# %%
df
# Out:
#      0   1    2
# 0  1.0 NaN  3.0
# 1  4.0 NaN  5.0
# 2  NaN NaN  NaN

# %%
df.dropna(axis=1, how='all')
# Out:
#      0    2
# 0  1.0  3.0
# 1  4.0  5.0
# 2  NaN  NaN

# %%
df.fillna(0)
# Out:
#      0    1    2
# 0  1.0  0.0  3.0
# 1  4.0  0.0  5.0
# 2  0.0  0.0  0.0

# %%
df.fillna({0:15, 1:25, 2:35})
# Out:
#       0     1     2
# 0   1.0  25.0   3.0
# 1   4.0  25.0   5.0
# 2  15.0  25.0  35.0

# %%
df.fillna(0, inplace=True) #df = df.fillna(0)

# %%
df
# Out:
#      0    1    2
# 0  1.0  0.0  3.0
# 1  4.0  0.0  5.0
# 2  0.0  0.0  0.0

# %%
df=pd.DataFrame([[1,2,3],[4,NA,5],
                 [NA,NA,NA]])
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0
# 2  NaN  NaN  NaN

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\AZubochenko\AppData\Local\Temp\ipykernel_7196\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  2.0  5.0
# 2  4.0  2.0  5.0

# %%
df.fillna(method="ffill", limit=1)
# Out:
# C:\Users\AZubochenko\AppData\Local\Temp\ipykernel_7196\2400329422.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", limit=1)
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  2.0  5.0
# 2  4.0  NaN  5.0

# %%
data=pd.Series([1,0,NA,5])
data
# Out:
# 0    1.0
# 1    0.0
# 2    NaN
# 3    5.0
# dtype: float64

# %%
data.fillna(data.mean())
# Out:
# 0    1.0
# 1    0.0
# 2    2.0
# 3    5.0
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  2.0  5.0
# 2  2.5  2.0  4.0
